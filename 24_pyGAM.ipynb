# %%
from pygam import LinearGAM, s, f
from pygam.datasets import wage

from modules.Utils.utils import loadFromDB, strategyTester
from modules.Utils.indicators import computeSuperTrend, addIndicators, computeLaggingLinearRegression, computeTrixIndicator,computeFutureLinearRegression, generateDatesFeatures
import pandas as pd
import numpy as np
from ta.trend import ema_indicator

from bokeh.plotting import figure
from bokeh.io import push_notebook,show, output_notebook
from bokeh.models import HoverTool, Band, ColumnDataSource
output_notebook()
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Regression

# %%
SYMBOL= 'BTC'
df = loadFromDB(f'../backtest_tools/database/database/Binance/1h/{SYMBOL}-USDT.csv').iloc[-13000:]
df = addIndicators(df)
df = computeLaggingLinearRegression(df, 'Close',20, False)
df = computeTrixIndicator(df, col='Close')
df.dropna(inplace=True)
# Technical indicators
from scipy.signal import savgol_filter

from statsmodels.tsa.filters.hp_filter import hpfilter

def filterData(data, method='savgol')->np.array:
    """function the filter a signal with a specific method.

    Args:
        data (np.array): The input signal to denoise.
        method (str): The filtering/denoising method. Default to 'savgol'.

    Returns:
        np.array: The filtered signal.
    """
    if method=='savgol':
        return savgol_filter(data, 30, 2, mode='nearest')
    elif method=='hpf':
        cycle, trend = hpfilter(data,120)
        return trend

df['EMA20_denoised'] = filterData(df['EMA20'], method='hpf')
df['EMA20_denoised_diff'] = df.EMA20_denoised.diff(1)

#df = df[[metric]]

lags = 5; cols = []

for lag in range(1, lags + 1):
    col = f'lag_{lag}'
    df[col] = df['EMA20'].shift(lag)
    
df = generateDatesFeatures(df)
df.dropna(inplace=True)
print(df.columns)
print(df.shape)
df.head()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Timestamp', 'High_Low_diff',
#        'EMA20', 'EMA50', 'EMA100', 'EMA200', 'MACD', 'Stoch_RSI', 'Vortex',
#        'Bollinger_low', 'Bollinger_high', 'ADX', 'ATR', 'CCI', 'OVB',
#        'OVB_EMA200', 'EVM', 'B_MLR_coefs', 'B_MLR_coefs_diff', 'Trix',
#        'Trix_histo', 'EMA20_denoised', 'EMA20_denoised_diff', 'lag_1', 'lag_2',
#        'lag_3', 'lag_4', 'lag_5', 'Day', 'Month', 'Year', 'Day_week', 'Week',
#        'Hour', 'Day_sin', 'Day_cos', 'Year_sin', 'Year_cos'],
#       dtype='object')
# (12728, 43)
#                          Open      High       Low     Close       Volume  \
# Date
# 2021-03-23 17:00:00  55165.20  55760.00  54830.01  55548.52  2642.910640
# 2021-03-23 18:00:00  55548.52  55767.01  55401.00  55710.87  2130.555350
# 2021-03-23 19:00:00  55705.78  55830.90  55362.18  55364.69  1880.519753
# 2021-03-23 20:00:00  55364.68  55541.81  54825.42  55008.46  2847.211367
# ...

# %% [markdown]
# ## Fear and Greed

# %%
import requests
import json
from datetime import datetime
import numpy as np
response_fng = requests.get('https://api.alternative.me/fng/?limit=0&format=json').text
df_fng = pd.DataFrame(json.loads(response_fng)['data'])
df_fng.drop(columns=['time_until_update'],inplace=True)
df_fng.rename(columns={'timestamp':'date'},inplace=True)
df_fng['date'] = df_fng['date'].astype(int).apply(lambda x: datetime.fromtimestamp(x))
df_fng.sort_values('date',inplace=True)
df_fng.set_index('date',inplace=True)
print(f'{len(df_fng)} total records')
def addFNG(x):
    try:
        return int(df_fng.loc[pd.to_datetime(x.name).date().strftime("%Y-%m-%d")].value.values[0])
    except:
        return np.nan
df['FnG'] = df.apply(addFNG,axis=1)
# Out:
# 1675 total records

# %% [markdown]
# ## G Trends

# %%
from pytrends.request import TrendReq
import pytz

pytrends = TrendReq(hl='fr-FR', tz=360) 
kw_list = ["BTC","Blockchain","Bitcoin"] # list of keywords to get data 

pytrends.build_payload(kw_list, cat=0, timeframe='today 12-m') 
gtrends_data = pytrends.get_historical_interest(kw_list,
                                        year_start=df.index[0].year,
                                        month_start=df.index[0].month,
                                        day_start=df.index[0].day,
                                        hour_start=df.index[0].hour,
                                        year_end=df.index[-1].year,
                                        month_end=df.index[-1].month,
                                        day_end=df.index[-1].day,
                                        hour_end=df.index[-1].hour,
                                        cat=0, sleep=5,frequency='hourly')
def addTimestampToDf(df)->pd.DataFrame:
    """add timestamp to dataframe as column

    Args:
        df (pd.DataFrame): The Dataframe we want to add timestamp as col

    Returns:
        pd.DataFrame: The Dataframe with the new column
    """
    df['Timestamp'] = [round(datetime.timestamp(df.index[ind])) for ind in range(len(df.index))]
    df['Timestamp'] = df['Timestamp'].astype(int)
    return df
gtrends_data = addTimestampToDf(gtrends_data)

gtrends_data = gtrends_data.drop_duplicates(subset=['Timestamp'],keep='first')
print(len(gtrends_data))
gtrends_data['BTC'] = gtrends_data.apply(lambda x: x['BTC']+x['Bitcoin']+x['Blockchain'], axis=1)
gtrends_data.drop(columns=['Bitcoin','isPartial','Blockchain'], inplace=True)
def removeMissingData(left_df:pd.DataFrame,right_df:pd.DataFrame,left_key:str,right_key:str,mode:str='inner'):
    """remove missing data from left and right dataframe
    """
    if mode=='inner':
        excess_left = list(set(left_df[left_key].values) - set(right_df[right_key].values))
        for i in excess_left:
            left_df.drop(left_df.loc[left_df[left_key]==i].index, inplace=True)
            
        excess_right = list(set(right_df[right_key].values)-set(left_df[left_key].values))
        for i in excess_right:
            right_df.drop(right_df.loc[right_df[right_key]==i].index, inplace=True)    
        return left_df,right_df
    elif mode=='right':
        excess_right = list(set(right_df[right_key].values)-set(left_df[left_key].values))
        for i in excess_right:
            right_df.drop(right_df.loc[right_df[right_key]==i].index, inplace=True)   
        return left_df,right_df
    elif mode=='left':
        excess_left = list(set(left_df[left_key].values) - set(right_df[right_key].values))
        for i in excess_left:
            left_df.drop(left_df.loc[left_df[left_key]==i].index, inplace=True)
        return left_df,right_df
    else:
        print('Error wrong mode...')
        return 0
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
gtrends_data_bckup = gtrends_data.copy()
df,gtrends_data = removeMissingData(df,gtrends_data,'Timestamp','Timestamp')
df['G_trend'] = gtrends_data['BTC']
df.head()
# Out:
#                          Open      High       Low     Close       Volume  \
# Date
# 2021-03-23 17:00:00  55165.20  55760.00  54830.01  55548.52  2642.910640
# 2021-03-23 18:00:00  55548.52  55767.01  55401.00  55710.87  2130.555350
# 2021-03-23 19:00:00  55705.78  55830.90  55362.18  55364.69  1880.519753
# 2021-03-23 20:00:00  55364.68  55541.81  54825.42  55008.46  2847.211367
# 2021-03-23 21:00:00  55008.45  55080.16  54318.70  54452.60  2952.881221
#
#                       Timestamp  High_Low_diff         EMA20         EMA50  \
# Date
# 2021-03-23 17:00:00  1616515200         929.99  55034.371096  55820.659199
# 2021-03-23 18:00:00  1616518800         366.01  55098.799563  55816.353741
# 2021-03-23 19:00:00  1616522400         468.72  55124.122462  55798.641437
# 2021-03-23 20:00:00  1616526000         716.39  55113.106990  55767.653930
# 2021-03-23 21:00:00  1616529600         761.46  55050.201562  55716.083187
#
# ...

# %%
df.dropna(inplace=True)

# %%
# plot the heatmap
fig, ax = plt.subplots(1, figsize=(25,15))
import seaborn as sns

sns.heatmap(df.corr(), annot=True, cmap='coolwarm',
        xticklabels=df.columns,
        yticklabels=df.columns,ax=ax)
# Out:
# <AxesSubplot:>

# %%
offset=1
metric = 'B_MLR_coefs_denoised'

X = df[['Open', 'High', 'Low', 'Close', 'Volume', 'Timestamp', 'High_Low_diff',
       'EMA20', 'EMA50', 'EMA100', 'EMA200', 'MACD', 'Stoch_RSI', 'Vortex',
       'Bollinger_low', 'Bollinger_high', 'ADX', 'ATR', 'CCI', 'OVB',
       'OVB_EMA200', 'EVM', 'B_MLR_coefs','Trix', 'Trix_histo', 'lag_1',
       'lag_2', 'lag_3', 'lag_4', 'lag_5', 'Day', 'Month', 'Year', 'Day_week',
       'Week', 'Hour', 'Day_sin', 'Day_cos', 'Year_sin', 'Year_cos']].iloc[:-offset].values

y = df[[metric]].iloc[offset:].values.reshape(-1)

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression

select = SelectKBest(score_func=f_regression, k=14)
z = select.fit_transform(X,y)
X=z

# %% [markdown]
# ## Normalization

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

feature_scaler = StandardScaler()
X_scaled = feature_scaler.fit_transform(X)
label_scaler = StandardScaler()
y_scaled = label_scaler.fit_transform(y.reshape(-1, 1))

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2,shuffle=True)

# %%
## model

gam = LinearGAM(s(0, constraints='monotonic_inc') ,verbose=True).gridsearch(X_train, y_train.reshape(-1))

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error


y_test_pred_inv = label_scaler.inverse_transform(gam.predict(X_test).reshape(-1,1)).reshape(1,-1)[0]
y_test_inv = label_scaler.inverse_transform(y_test).reshape(1,-1)[0]

print('# On the test dataset : ')
print(f"MAE: {mean_absolute_error(y_test_inv, y_test_pred_inv)}")
print(f"MSE: {mean_squared_error(y_test_inv, y_test_pred_inv)}")
print(f"MAPE: {mean_absolute_percentage_error(y_test_inv, y_test_pred_inv)*100} %")


y_pred_inv = label_scaler.inverse_transform(gam.predict(X_scaled).reshape(1,-1)).reshape(1,-1)[0]
y_inv = label_scaler.inverse_transform(y_scaled).reshape(1,-1)[0]

print('# On whole dataset : ')
print(f"MAE: {mean_absolute_error(y_inv, y_pred_inv)}")
print(f"MSE: {mean_squared_error(y_inv, y_pred_inv)}")
print(f"MAPE: {mean_absolute_percentage_error(y_inv, y_pred_inv)*100} %")
# Out:
#   0% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
#   9% (1 of 11) |##                       | Elapsed Time: 0:00:00 ETA:   0:00:02
#  18% (2 of 11) |####                     | Elapsed Time: 0:00:00 ETA:   0:00:02
#  27% (3 of 11) |######                   | Elapsed Time: 0:00:00 ETA:   0:00:01
#  36% (4 of 11) |#########                | Elapsed Time: 0:00:00 ETA:   0:00:01
#  45% (5 of 11) |###########              | Elapsed Time: 0:00:01 ETA:   0:00:01
#  54% (6 of 11) |#############            | Elapsed Time: 0:00:01 ETA:   0:00:00
#  63% (7 of 11) |###############          | Elapsed Time: 0:00:01 ETA:   0:00:00
#  72% (8 of 11) |##################       | Elapsed Time: 0:00:01 ETA:   0:00:00
#  81% (9 of 11) |####################     | Elapsed Time: 0:00:01 ETA:   0:00:00
#  90% (10 of 11) |#####################   | Elapsed Time: 0:00:02 ETA:   0:00:00
# 100% (11 of 11) |########################| Elapsed Time: 0:00:02 Time:  0:00:02
# ...

# %%
p = figure(title=f"Prediction on {metric}", x_axis_label='time', y_axis_label='value ($)',width=1500, height=600,)
# Add the HoverTool to the figure
p.add_tools(HoverTool(
    tooltips=[
    ("Price", "@y{0.00} $"),
], formatters={
        '$x': 'printf',
        '$y' : 'printf',
    },
    mode='vline'
))
p.line(list(range(len(X))), y_inv, legend_label="real data", line_width=2, )
p.line(list(range(len(X))), y_pred_inv, legend_label="prediction data", line_width=2, color='orange')

#source = ColumnDataSource({
#        'base':list(range(len(X))),
#        'lower':[lower[0] for lower in gam.prediction_intervals(X, width=.95)],
#        'upper':[upper[1] for upper in gam.prediction_intervals(X, width=.95)]
#        })
#
#band = Band(base='base', lower='lower', upper='upper',source=source, level='underlay',
#            fill_alpha=1.0, line_width=1, line_color='black')
#
#p.add_layout(band)
p.legend.location = "top_left"
show(p)
# Out:
#   <div class="bk-root" id="9d08d1ff-7b5d-4744-b114-87014bdff962" data-root-id="1471"></div>

# %%
df['Pred_lr'] = np.nan 
df['Pred_lr'].iloc[:-offset] = y_pred_inv
df['Pred_lr_diff'] = df['Pred_lr'].diff(2)

df = df.dropna()

# %%
df['EMA20_denoised'] = df['EMA20_denoised'].diff(1)

# %%
def buyCondition(row:pd.Series, previous_row:pd.Series=None)->bool:
    return True if (row['Pred_lr_diff']>0) else False

def sellCondition(row:pd.Series, previous_row:pd.Series=None)->bool:
    return True if (row['Pred_lr_diff']<0)else False

strategyTester(df,buyCondition,sellCondition,equity=1000,)
# Out:
# Period : [2021-01-13 06:00:00] -> [2022-08-28 23:00:00]
# Starting balance : 1000 $
#
# ----- General Informations -----
# Final balance : 446.75 $
# Performance vs US Dollar : -55.32 %
# Buy and Hold Performence : -40.08 %
# Performance vs Buy and Hold : 38.04 %
# Best trade : +19.54 %, the 2021-02-10 03:00:00
# Worst trade : -7.65 %, the 2022-05-11 14:00:00
# Worst drawBack : -64.0 %
# Total fees :  735.4 $
#
# ----- Trades Informations -----
# Total trades on period : 628
# Number of positive trades : 160
# Number of negative trades :  468
# Trades win rate ratio : 25.48 %
# Average trades performance : -0.03 %
# Average positive trades : 2.96 %
# Average negative trades : -1.05 %
#
# ----- Plot -----

# %% [markdown]
# # Classification

# %%
SYMBOL= 'BTC'
df = loadFromDB(f'../backtest_tools/database/database/KuCoin/1h/{SYMBOL}-USDT.csv')
df = addIndicators(df)
df = computeLaggingLinearRegression(df, 'Close',20, False)
df = computeTrixIndicator(df, col='Close')
df.dropna(inplace=True)
# Technical indicators
from scipy.signal import savgol_filter

from statsmodels.tsa.filters.hp_filter import hpfilter

def filterData(data, method='savgol')->np.array:
    """function the filter a signal with a specific method.

    Args:
        data (np.array): The input signal to denoise.
        method (str): The filtering/denoising method. Default to 'savgol'.

    Returns:
        np.array: The filtered signal.
    """
    if method=='savgol':
        return savgol_filter(data, 30, 2, mode='nearest')
    elif method=='hpf':
        cycle, trend = hpfilter(data,120)
        return trend

df['EMA20_denoised'] = filterData(df['EMA20'], method='hpf')
df['EMA20_denoised_diff'] = df.EMA20_denoised.diff(1)
metric = 'Target'
#df = df[[metric]]

df['Target'] = df.apply(lambda row: 1 if row['EMA20_denoised_diff']>0 else 0, axis=1)
df.dropna(  inplace=True)

lags = 5; cols = []

for lag in range(1, lags + 1):
    col = f'lag_{lag}'
    df[col] = df['Target'].shift(lag)
    
df = generateDatesFeatures(df)
df.dropna(inplace=True)
print(df.columns)
print(df.shape)
df.head()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Timestamp', 'High_Low_diff',
#        'EMA20', 'EMA50', 'EMA100', 'EMA200', 'MACD', 'Stoch_RSI', 'Vortex',
#        'Bollinger_low', 'Bollinger_high', 'ADX', 'ATR', 'CCI', 'OVB',
#        'OVB_EMA200', 'EVM', 'B_MLR_coefs', 'B_MLR_coefs_diff', 'Trix',
#        'Trix_histo', 'EMA20_denoised', 'EMA20_denoised_diff', 'Target',
#        'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'Day', 'Month', 'Year',
#        'Day_week', 'Week', 'Hour', 'Day_sin', 'Day_cos', 'Year_sin',
#        'Year_cos'],
#       dtype='object')
# (21520, 44)
#                        Open    High     Low   Close     Volume   Timestamp  \
# Date
# 2020-01-12 10:00:00  8138.5  8167.2  8120.9  8136.8  65.891557  1578819600
# 2020-01-12 11:00:00  8136.7  8138.8  8099.0  8121.3  51.434659  1578823200
# 2020-01-12 12:00:00  8121.4  8129.4  8104.9  8110.8  21.660442  1578826800
# 2020-01-12 13:00:00  8111.5  8152.4  8111.5  8134.1  38.511487  1578830400
# ...

# %%
fig, ax = plt.subplots(1, figsize=(25,15))
import seaborn as sns

sns.heatmap(df.corr(), annot=True, cmap='coolwarm',
        xticklabels=df.columns,
        yticklabels=df.columns,ax=ax)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Timestamp', 'High_Low_diff',
#        'EMA20', 'EMA50', 'EMA100', 'EMA200', 'MACD', 'Stoch_RSI', 'Vortex',
#        'Bollinger_low', 'Bollinger_high', 'ADX', 'ATR', 'CCI', 'OVB',
#        'OVB_EMA200', 'EVM', 'B_MLR_coefs', 'B_MLR_coefs_diff', 'Trix',
#        'Trix_histo', 'EMA20_denoised', 'EMA20_denoised_diff', 'Target',
#        'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'Day', 'Month', 'Year',
#        'Day_week', 'Week', 'Hour', 'Day_sin', 'Day_cos', 'Year_sin',
#        'Year_cos'],
#       dtype='object')

# %%
offset=1

X = df[['Open', 'High', 'Low', 'Close', 'Volume', 'Timestamp', 'High_Low_diff',
       'EMA20', 'EMA50', 'EMA100', 'EMA200', 'MACD', 'Stoch_RSI', 'Vortex',
       'Bollinger_low', 'Bollinger_high', 'ADX', 'ATR', 'CCI', 'OVB',
       'OVB_EMA200', 'EVM', 'B_MLR_coefs', 'B_MLR_coefs_diff', 'Trix',
       'Trix_histo', 'EMA20_denoised', 'EMA20_denoised_diff', 'Target',
       'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'Day', 'Month', 'Year',
       'Day_week', 'Week', 'Hour', 'Day_sin', 'Day_cos', 'Year_sin',
       'Year_cos']].iloc[:-offset].values

y = df[[metric]].iloc[offset:].values.reshape(-1)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression

select = SelectKBest(score_func=f_regression, k=6)
z = select.fit_transform(X,y)
X=z

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

feature_scaler = StandardScaler()
X_scaled = feature_scaler.fit_transform(X)
label_scaler = StandardScaler()
y_scaled = y

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2,shuffle=True)

# %%
## model
from pygam import LogisticGAM, s, f
gam = LogisticGAM(s(0, constraints='monotonic_inc') ,verbose=True).gridsearch(X_train, y_train)


gam.accuracy(X_test, y_test)
# Out:
#   0% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
#   9% (1 of 11) |##                       | Elapsed Time: 0:00:00 ETA:   0:00:07
#  18% (2 of 11) |####                     | Elapsed Time: 0:00:01 ETA:   0:00:05
#  27% (3 of 11) |######                   | Elapsed Time: 0:00:01 ETA:   0:00:04
#  36% (4 of 11) |#########                | Elapsed Time: 0:00:02 ETA:   0:00:04
#  45% (5 of 11) |###########              | Elapsed Time: 0:00:03 ETA:   0:00:04
#  54% (6 of 11) |#############            | Elapsed Time: 0:00:03 ETA:   0:00:03
#  63% (7 of 11) |###############          | Elapsed Time: 0:00:04 ETA:   0:00:02
#  72% (8 of 11) |##################       | Elapsed Time: 0:00:04 ETA:   0:00:01
#  81% (9 of 11) |####################     | Elapsed Time: 0:00:04 ETA:   0:00:00
#  90% (10 of 11) |#####################   | Elapsed Time: 0:00:05 ETA:   0:00:00
# 100% (11 of 11) |########################| Elapsed Time: 0:00:05 Time:  0:00:05
# ...

# %%
df['Pred'] = np.nan
df['Pred'].iloc[:-offset] = gam.predict(X_scaled)
df.dropna(inplace=True)
df
# Out:
#                         Open     High      Low    Close      Volume  \
# Date
# 2020-01-11 11:00:00   8113.4   8114.9   8047.0   8056.3   59.086505
# 2020-01-11 12:00:00   8055.6   8071.9   7992.4   8042.4   80.879133
# 2020-01-11 13:00:00   8043.0   8067.5   8021.4   8061.0   48.344039
# 2020-01-11 14:00:00   8061.1   8100.0   8048.2   8092.2   57.998455
# 2020-01-11 15:00:00   8092.1   8116.5   8053.5   8054.8   44.848336
# ...                      ...      ...      ...      ...         ...
# 2022-08-28 19:00:00  19991.2  20054.0  19953.6  19981.2  270.364289
# 2022-08-28 20:00:00  19981.1  20040.3  19976.7  20009.9   86.616895
# 2022-08-28 21:00:00  20009.9  20061.9  19956.0  19971.9  156.061512
# 2022-08-28 22:00:00  19971.8  20046.9  19963.1  19988.9  126.502289
# 2022-08-28 23:00:00  19988.9  20046.8  19944.1  19964.8  127.077961
#
#                       Timestamp  High_Low_diff         EMA20         EMA50  \
# Date
# ...

# %%
def buyCondition(row:pd.Series, previous_row:pd.Series=None)->bool:
    return row['Pred'] #True if (row['EMA20_denoised']>0) else False

def sellCondition(row:pd.Series, previous_row:pd.Series=None)->bool:
    return row['Pred'] #True if (row['EMA20_denoised']<0)else False

strategyTester(df.iloc[-2000:],buyCondition,sellCondition,equity=1000,)
# Out:
# Period : [2022-06-06 15:00:00] -> [2022-08-28 23:00:00]
# Starting balance : 1000 $
#
# ----- General Informations -----
# Final balance : 401.73 $
# Performance vs US Dollar : -59.83 %
# Buy and Hold Performence : -36.51 %
# Performance vs Buy and Hold : 63.87 %
# Best trade : +3.63 %, the 2022-08-10 14:00:00
# Worst trade : -9.96 %, the 2022-07-13 17:00:00
# Worst drawBack : -60.0 %
# Total fees :  409.15 $
#
# ----- Trades Informations -----
# Total trades on period : 463
# Number of positive trades : 204
# Number of negative trades :  259
# Trades win rate ratio : 44.06 %
# Average trades performance : -0.12 %
# Average positive trades : 0.55 %
# Average negative trades : -0.65 %
#
# ----- Plot -----
